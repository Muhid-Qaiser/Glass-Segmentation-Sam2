# %%
from ultralytics import SAM

# Load a model
model = SAM("sam2_b.pt")

# Run inference
model("data_sam2/train/4k2uj4r_glass_625x300_11_March_21_jpg.rf.2a04e243051b21a0ab8faf714991aaff.jpg")
# Out:
# image 1/1 d:\D-Documents\Self-Improvement\Python\Computer Vision\Liquid-Research\SAM2\data_sam2\train\4k2uj4r_glass_625x300_11_March_21_jpg.rf.2a04e243051b21a0ab8faf714991aaff.jpg: 1024x1024 1 0, 1 1, 3105.0ms
# Speed: 7.0ms preprocess, 3105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 1024, 1024)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: '0', 1: '1'}
#  obb: None
#  orig_img: array([[[187, 164, 132],
#          [187, 164, 132],
#          [188, 165, 133],
#          ...,
#          [179, 156, 118],
#          [181, 158, 120],
#          [182, 159, 121]],
#
#         [[186, 163, 131],
#          [187, 164, 132],
#          [187, 164, 132],
#          ...,
#          [178, 155, 117],
#          [180, 157, 119],
#          [181, 158, 120]],
#
#         [[186, 163, 131],
#          [186, 163, 131],
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('data_sam2/train/4k2uj4r_glass_625x300_11_March_21_jpg.rf.2a04e243051b21a0ab8faf714991aaff.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
from ultralytics import SAM

# Load the SAM-2 model
model = SAM("sam2_l.pt")

# Path to the image
image_path = "data_sam2/train/4k2uj4r_glass_625x300_11_March_21_jpg.rf.2a04e243051b21a0ab8faf714991aaff.jpg"

# Run inference and specify the save directory
results = model(image_path , points=[[300, 400], [300, 200]], labels=[1, 0])
# results = model(image_path , points=[[300, 400]], labels=[1])
# Out:
# ...
# 100%|██████████| 428M/428M [00:38<00:00, 11.6MB/s]
# image 1/1 d:\D-Documents\Self-Improvement\Python\Computer Vision\Liquid-Research\SAM2\data_sam2\train\4k2uj4r_glass_625x300_11_March_21_jpg.rf.2a04e243051b21a0ab8faf714991aaff.jpg: 1024x1024 1 0, 1 1, 463.6ms
# Speed: 7.0ms preprocess, 463.6ms inference, 1.0ms postprocess per image at shape (1, 3, 1024, 1024)

# %%
results[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>
